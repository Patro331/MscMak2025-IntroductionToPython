# %% [markdown]
# <a href="https://colab.research.google.com/github/Patro331/MscMak2025-IntroductionToPython/blob/main/Descriptive_Data_Analysis_11_09_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descriptive Data Analysis
#
# We'll use California Housing Dataset to perform a Descriptive Data Analysis
#
# We'll addresses 15 core descriptive
# analysis questions grouped into 5 analytical themes:
#
# 1. Dataset Overview & Data Quality Assessment
# 2. Univariate Descriptive Statistics & Distribution Analysis
# 3. Derived Feature Engineering & Ratio Analysis
# 4. Spatial & Geographic Segmentation
# 5. Bivariate Relationships & Segment Insights

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np

# %%
#Loading the data
caly_data= pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
caly_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
caly_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# #

# %% [markdown]
# #Descriptive Analysis Questions
#
# 1.   What are the structural dimensions of the dataset?
# 2.   What are the feature data types, missing value counts, and memory footprint?
# 3. Are there duplicate records or invalid geographical coordinates?
# 4. What are the central tendencies and dispersion measures (mean, median, std, IQR, min, max)?
# 5. How skewed are the statistical distributions of features?
# 6. Are there artificial caps/ceilings present in features like age?
# 7. What is the distribution of average rooms per household?
# 8. What proportion of total rooms are bedrooms?
# 9. What is the household occupancy density (population per household)?
# 10. What is the geographic spatial extent (bounding box) of the dataset?
# 11. How do housing metrics compare between Northern and Southern California? Note: Threshold lat ~36.0N roughly splits South Caly and North Caly
# 12. Which features correlate most strongly with median house value?
# 13. How do house values and ratios differ across Median Income Quartiles?
# 14. How do housing characteristics vary across property age brackets?
# 15. What key differences separate the top 10% highest income blocks from the bottom 10%?
